# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\customers_raw.csv")
print(df.head())
# Out:
#   customer_id first_name last_name                     email         phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com  9.876543e+09
# 1        C002      Priya     Patel     priya.patel@yahoo.com -9.988777e+09
# 2        C003       Amit     Kumar                       NaN  9.765432e+09
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com  9.123457e+09
# 4        C005     Vikram     Singh  vikram.singh@outlook.com  9.988112e+09
#
#         city registration_date
# 0  Bangalore         1/15/2023
# 1     Mumbai         2/20/2023
# 2      Delhi         3/10/2023
# 3  Hyderabad        15/04/2023
# 4    Chennai         5/22/2023

# %%
import pandas as pd

customers = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\customers_raw.csv")
products = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\products_raw.csv")
sales = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\sales_raw.csv")

print(customers.shape)
print(products.shape)
print(sales.shape)
# Out:
# (26, 7)
# (20, 5)
# (41, 7)

# %%
print(customers.columns)
print(products.columns)
print(sales.columns)
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'email', 'phone', 'city',
#        'registration_date'],
#       dtype='object')
# Index(['product_id', 'product_name', 'category', 'price', 'stock_quantity'], dtype='object')
# Index(['transaction_id', 'customer_id', 'product_id', 'quantity', 'unit_price',
#        'transaction_date', 'status'],
#       dtype='object')

# %%
customers.drop_duplicates(inplace=True)
products.drop_duplicates(inplace=True)
sales.drop_duplicates(inplace=True)

# %%
products["price"].fillna(products["price"].mean(), inplace=True)
products["stock_quantity"].fillna(0, inplace=True)
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_37072\3634521823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products["price"].fillna(products["price"].mean(), inplace=True)
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_37072\3634521823.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import re

def standardize_phone(phone):
    if pd.isna(phone):
        return None
    digits = re.sub(r"\D", "", str(phone))
    if len(digits) == 10:
        return "+91-" + digits
    return None

customers["phone"] = customers["phone"].apply(standardize_phone)

# %%
products["category"] = products["category"].str.strip().str.title()

# %%
customers["registration_date"] = pd.to_datetime(
    customers["registration_date"].astype(str),
    errors="coerce"
).dt.date

# %%
sales["transaction_date"] = pd.to_datetime(
    sales["transaction_date"].astype(str),
    errors="coerce"
).dt.date

# %%
products.drop_duplicates(inplace=True)

# %%
products["price"].fillna(products["price"].mean(), inplace=True)
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_37072\4141675214.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products["price"].fillna(products["price"].mean(), inplace=True)

# %%
products["stock_quantity"].fillna(0, inplace=True)
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_37072\1432779919.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products["stock_quantity"].fillna(0, inplace=True)

# %%
sales.drop_duplicates(inplace=True)

# %%
sales.dropna(subset=["customer_id", "product_id"], inplace=True)

# %%
import numpy as np

customers["email"] = customers["email"].replace(r'^\s*$', np.nan, regex=True)

# %%
print(customers["email"].isna().sum())
print(customers["email"].head(10))
# Out:
# 5
# 0      rahul.sharma@gmail.com
# 1       priya.patel@yahoo.com
# 2                         NaN
# 3       sneha.reddy@gmail.com
# 4    vikram.singh@outlook.com
# 5      anjali.mehta@gmail.com
# 6                         NaN
# 7        pooja.iyer@gmail.com
# 8      karthik.nair@yahoo.com
# 9       deepa.gupta@gmail.com
# Name: email, dtype: object

# %%
customers["email"] = customers["email"].fillna(
    customers.index.to_series().apply(lambda i: f"unknown_{i}@mail.com")
)

# %%
# %pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

customers = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\customers_raw.csv")
print(customers.head())
# Out:
#   customer_id first_name last_name                     email         phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com  9.876543e+09
# 1        C002      Priya     Patel     priya.patel@yahoo.com -9.988777e+09
# 2        C003       Amit     Kumar                       NaN  9.765432e+09
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com  9.123457e+09
# 4        C005     Vikram     Singh  vikram.singh@outlook.com  9.988112e+09
#
#         city registration_date
# 0  Bangalore         1/15/2023
# 1     Mumbai         2/20/2023
# 2      Delhi         3/10/2023
# 3  Hyderabad        15/04/2023
# 4    Chennai         5/22/2023

# %%
import pandas as pd
import numpy as np
import re


customers = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\customers_raw.csv")


customers.drop_duplicates(inplace=True)

customers["email"] = customers["email"].replace(r'^\s*$', np.nan, regex=True)


customers["email"] = customers["email"].fillna(
    customers.index.to_series().apply(lambda i: f"unknown_{i}@mail.com")
)




customers["registration_date"] = pd.to_datetime(
    customers["registration_date"].astype(str),
    errors="coerce"
).dt.date




print(customers.head())
print("Missing emails:", customers["email"].isna().sum())
# Out:
#   customer_id first_name last_name                     email         phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com  9.876543e+09
# 1        C002      Priya     Patel     priya.patel@yahoo.com -9.988777e+09
# 2        C003       Amit     Kumar        unknown_2@mail.com  9.765432e+09
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com  9.123457e+09
# 4        C005     Vikram     Singh  vikram.singh@outlook.com  9.988112e+09
#
#         city registration_date
# 0  Bangalore        2023-01-15
# 1     Mumbai        2023-02-20
# 2      Delhi        2023-03-10
# 3  Hyderabad               NaT
# 4    Chennai        2023-05-22
# Missing emails: 0

# %%
print(customers.isna().sum())
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                0
# phone                0
# city                 0
# registration_date    2
# dtype: int64

# %%
def standardize_phone(phone):
    if pd.isna(phone):
        return None

    digits = re.sub(r"\D", "", str(phone))

    if len(digits) == 12 and digits.startswith("91"):
        return "+91-" + digits[2:]

    if len(digits) == 10:
        return "+91-" + digits

    return None

# %%
customers["phone"]
# Out:
# 0     9.876543e+09
# 1    -9.988777e+09
# 2     9.765432e+09
# 3     9.123457e+09
# 4     9.988112e+09
# 5     9.876543e+09
# 6     9.198770e+11
# 7     9.123457e+09
# 8     9.988777e+09
# 9     9.871235e+09
# 11    9.876510e+09
# 12    9.988001e+09
# 13    9.123410e+09
# 14   -9.876543e+09
# 15    9.988777e+09
# 16    9.123457e+09
# 17    9.876123e+09
# 18    9.988112e+09
# 19    9.876543e+09
# 20    9.123457e+09
# 21    9.199890e+11
# 22    9.876543e+09
# 23    9.988112e+09
# 24    9.123457e+09
# 25    9.876543e+09
# Name: phone, dtype: float64

# %%
customers["phone"] = customers["phone"].astype(str)
import re
import pandas as pd

def standardize_phone(phone):
    if phone in ["nan", "None", ""]:
        return None

   
    phone = phone.replace(".0", "")

    digits = re.sub(r"\D", "", phone)

    
    if len(digits) > 12:
        return None

    
    if len(digits) == 12 and digits.startswith("91"):
        return "+91-" + digits[2:]

    if len(digits) == 10:
        return "+91-" + digits

    return None

customers["phone"] = customers["phone"].apply(standardize_phone)

# %%
# %pip install cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(customers.head())
# Out:
#   customer_id first_name last_name                     email           phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com  +91-9876543210
# 1        C002      Priya     Patel     priya.patel@yahoo.com  +91-9988776564
# 2        C003       Amit     Kumar        unknown_2@mail.com  +91-9765432109
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com  +91-9123456789
# 4        C005     Vikram     Singh  vikram.singh@outlook.com  +91-9988112233
#
#         city registration_date
# 0  Bangalore        2023-01-15
# 1     Mumbai        2023-02-20
# 2      Delhi        2023-03-10
# 3  Hyderabad               NaT
# 4    Chennai        2023-05-22

# %%
print(customers.isna().sum())
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                0
# phone                0
# city                 0
# registration_date    2
# dtype: int64

# %%
engine = create_engine(
    "mysql+pymysql://root:Y#Saisneha2004D@localhost/fleximart"
)

# %%
customers_to_load = customers[
    ["first_name", "last_name", "email", "phone", "city", "registration_date"]
]

customers_to_load.to_sql(
    "customers",
    engine,
    if_exists="append",
    index=False
)

print("Customers loaded successfully into SQL")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
# ...

# %%
print(customers_to_load.head())
# Out:
#   first_name last_name                     email           phone       city  \
# 0      Rahul    Sharma    rahul.sharma@gmail.com  +91-9876543210  Bangalore
# 1      Priya     Patel     priya.patel@yahoo.com  +91-9988776564     Mumbai
# 2       Amit     Kumar        unknown_2@mail.com  +91-9765432109      Delhi
# 3      Sneha     Reddy     sneha.reddy@gmail.com  +91-9123456789  Hyderabad
# 4     Vikram     Singh  vikram.singh@outlook.com  +91-9988112233    Chennai
#
#   registration_date
# 0        2023-01-15
# 1        2023-02-20
# 2        2023-03-10
# 3               NaT
# 4        2023-05-22

# %%
print(customers_to_load["registration_date"].dtype)
# Out:
# object

# %%
customers_to_load["email"].duplicated().sum()
# Out:
# np.int64(0)

# %%
print(customers.shape)
customers.head()
# Out:
# (25, 7)
#   customer_id first_name last_name                     email           phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com  +91-9876543210
# 1        C002      Priya     Patel     priya.patel@yahoo.com  +91-9988776564
# 2        C003       Amit     Kumar        unknown_2@mail.com  +91-9765432109
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com  +91-9123456789
# 4        C005     Vikram     Singh  vikram.singh@outlook.com  +91-9988112233
#
#         city registration_date
# 0  Bangalore        2023-01-15
# 1     Mumbai        2023-02-20
# 2      Delhi        2023-03-10
# 3  Hyderabad               NaT
# 4    Chennai        2023-05-22

# %%
customers_to_load = customers[
    ["first_name", "last_name", "email", "phone", "city", "registration_date"]
]

print(customers_to_load.head())
# Out:
#   first_name last_name                     email           phone       city  \
# 0      Rahul    Sharma    rahul.sharma@gmail.com  +91-9876543210  Bangalore
# 1      Priya     Patel     priya.patel@yahoo.com  +91-9988776564     Mumbai
# 2       Amit     Kumar        unknown_2@mail.com  +91-9765432109      Delhi
# 3      Sneha     Reddy     sneha.reddy@gmail.com  +91-9123456789  Hyderabad
# 4     Vikram     Singh  vikram.singh@outlook.com  +91-9988112233    Chennai
#
#   registration_date
# 0        2023-01-15
# 1        2023-02-20
# 2        2023-03-10
# 3               NaT
# 4        2023-05-22

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://etl_user:etl1234@localhost/fleximart"
)

customers_to_load = customers[
    ["first_name", "last_name", "email", "phone", "city", "registration_date"]
]

customers_to_load.to_sql(
    "customers",
    engine,
    if_exists="append",
    index=False
)

print("Customers loaded successfully ")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
# ...

# %%
import pandas as pd


products = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\products_raw.csv")


products.drop_duplicates(inplace=True)


products["price"] = products["price"].fillna(products["price"].mean())


products["stock_quantity"] = products["stock_quantity"].fillna(0)


products["category"] = products["category"].astype(str).str.strip().str.title()


print(products.head())
print(products.isna().sum())
# Out:
#   product_id        product_name     category         price  stock_quantity
# 0       P001  Samsung Galaxy S21  Electronics  45999.000000           150.0
# 1       P002  Nike Running Shoes      Fashion   3499.000000            80.0
# 2       P003   Apple MacBook Pro  Electronics  14141.529412            45.0
# 3       P004        Levi's Jeans      Fashion   2999.000000           120.0
# 4       P005     Sony Headphones  Electronics   1999.000000           200.0
# product_id        0
# product_name      0
# category          0
# price             0
# stock_quantity    0
# dtype: int64

# %%
products_to_load = products[
    ["product_name", "category", "price", "stock_quantity"]
]


products_to_load.to_sql(
    "products",
    engine,
    if_exists="append",
    index=False
)

print("Products loaded successfully 🎉")
# Out:
# Products loaded successfully 🎉

# %%
import pandas as pd


sales = pd.read_csv(r"C:\Users\Sneha\OneDrive\Attachments\projects\sales_raw.csv")


sales.drop_duplicates(inplace=True)


sales["transaction_date"] = pd.to_datetime(
    sales["transaction_date"],
    errors="coerce"
).dt.date


sales.dropna(subset=["customer_id", "product_id"], inplace=True)


print(sales.head())
print(sales.isna().sum())
# Out:
#   transaction_id customer_id product_id  quantity  unit_price  \
# 0           T001        C001       P001         1       45999
# 1           T002        C002       P004         2        2999
# 2           T003        C003       P007         1       52999
# 4           T005        C005       P009         3         650
# 5           T006        C006       P012         1       12999
#
#   transaction_date     status
# 0       2024-01-15  Completed
# 1       2024-01-16  Completed
# 2              NaT  Completed
# 4       2024-01-20  Completed
# 5       2024-01-22  Completed
# transaction_id      0
# customer_id         0
# product_id          0
# quantity            0
# unit_price          0
# transaction_date    1
# status              0
# dtype: int64

# %%
orders_to_load = sales.copy()


orders_to_load["customer_id"] = (
    orders_to_load["customer_id"]
    .str.replace("C", "", regex=False)
    .astype(int)
)


orders_to_load["order_date"] = orders_to_load["transaction_date"]


orders_to_load["total_amount"] = (
    orders_to_load["quantity"] * orders_to_load["unit_price"]
)


orders_to_load = orders_to_load[
    ["customer_id", "order_date", "total_amount", "status"]
]


print(orders_to_load.head())
print(orders_to_load.isna().sum())
# Out:
#    customer_id  order_date  total_amount     status
# 0            1  2024-01-15         45999  Completed
# 1            2  2024-01-16          5998  Completed
# 2            3         NaT         52999  Completed
# 4            5  2024-01-20          1950  Completed
# 5            6  2024-01-22         12999  Completed
# customer_id     0
# order_date      1
# total_amount    0
# status          0
# dtype: int64

# %%
valid_customers = pd.read_sql(
    "SELECT customer_id FROM customers",
    engine
)

valid_customer_ids = set(valid_customers["customer_id"])

# %%
orders_to_load = orders_to_load[
    orders_to_load["customer_id"].isin(valid_customer_ids)
]

print("Remaining orders:", len(orders_to_load))
# Out:
# Remaining orders: 35

# %%
customers_sql = pd.read_sql(
    "SELECT customer_id, email FROM customers",
    engine
)

customers_sql.head()
# Out:
#    customer_id                    email
# 0            6   anjali.mehta@gmail.com
# 1           11      arjun.rao@gmail.com
# 2           19  arun.pillai@outlook.com
# 3           10    deepa.gupta@gmail.com
# 4           16    divya.menon@gmail.com

# %%
orders_to_load = pd.DataFrame()

orders_to_load["customer_id"] = sales["customer_id"]
orders_to_load["order_date"] = sales["transaction_date"]
orders_to_load["total_amount"] = sales["quantity"] * sales["unit_price"]
orders_to_load["status"] = sales["status"]

print(orders_to_load.head())
# Out:
#    customer_id  order_date  total_amount     status
# 0            1  2024-01-15         45999  Completed
# 1            2  2024-01-16          5998  Completed
# 2            3         NaT         52999  Completed
# 4            5  2024-01-20          1950  Completed
# 5            6  2024-01-22         12999  Completed

# %%
sales["customer_id"] = (
    sales["customer_id"]
    .str.replace("C", "", regex=False)
    .astype(int)
)

sales[["customer_id"]].head()
# Out:
#    customer_id
# 0            1
# 1            2
# 2            3
# 4            5
# 5            6

# %%
valid_customers = pd.read_sql(
    "SELECT customer_id FROM customers",
    engine
)

orders_to_load = orders_to_load[
    orders_to_load["customer_id"].isin(valid_customers["customer_id"])
]

print("Rows to be loaded:", len(orders_to_load))
# Out:
# Rows to be loaded: 35

# %%
valid_ids = pd.read_sql(
    "SELECT customer_id FROM customers",
    engine
)["customer_id"]

orders_to_load = orders_to_load[
    orders_to_load["customer_id"].isin(valid_ids)
]

print("Rows to load:", len(orders_to_load))
# Out:
# Rows to load: 35

# %%
len(orders_to_load)
# Out:
# 35

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="etl_user",
    password="etl1234",
    database="fleximart",
    autocommit=True
)

cursor = conn.cursor()


cursor.execute("SET FOREIGN_KEY_CHECKS = 0;")

insert_query = """
INSERT INTO orders (customer_id, order_date, total_amount, status)
VALUES (%s, %s, %s, %s)
"""

for _, row in orders_to_load.iterrows():
    cursor.execute(
        insert_query,
        (
            int(row["customer_id"]),
            str(row["order_date"]),      
            float(row["total_amount"]),
            str(row["status"])
        )
    )


cursor.execute("SET FOREIGN_KEY_CHECKS = 1;")

cursor.close()
conn.close()

print("Orders loaded successfully 🎉")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[90], line 22
#      16 insert_query = """
#      17 INSERT INTO orders (customer_id, order_date, total_amount, status)
#      18 VALUES (%s, %s, %s, %s)
#      19 """
#      21 for _, row in orders_to_load.iterrows():
# ---> 22     cursor.execute(
#      23         insert_query,
#      24         (
#      25             int(row["customer_id"]),
#      26             str(row["order_date"]),      # force DATE as string
#      27             float(row["total_amount"]),
#      28             str(row["status"])
#      29         )
#      30     )
#      32 # turn FK checks back ON
#      33 cursor.execute("SET FOREIGN_KEY_CHECKS = 1;")
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
# ...

# %%
# drop rows with invalid order_date
orders_to_load = orders_to_load.dropna(subset=["order_date"])

print("Rows after removing NaT dates:", len(orders_to_load))
# Out:
# Rows after removing NaT dates: 34

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="etl_user",
    password="etl1234",
    database="fleximart",
    autocommit=True
)

cursor = conn.cursor()
cursor.execute("SET FOREIGN_KEY_CHECKS = 0;")

insert_query = """
INSERT INTO orders (customer_id, order_date, total_amount, status)
VALUES (%s, %s, %s, %s)
"""

for _, row in orders_to_load.iterrows():
    cursor.execute(
        insert_query,
        (
            int(row["customer_id"]),
            str(row["order_date"]),   
            float(row["total_amount"]),
            str(row["status"])
        )
    )

cursor.execute("SET FOREIGN_KEY_CHECKS = 1;")
cursor.close()
conn.close()

print("Orders loaded successfully")
# Out:
# Orders loaded successfully 🎉
